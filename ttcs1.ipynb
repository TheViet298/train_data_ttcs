# %% [markdown]
# <a href="https://colab.research.google.com/github/TheViet298/train_data_ttcs/blob/main/ttcs1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file_path = '/content/Total.csv'
df1 = pd.read_csv(file_path, encoding='ISO-8859-1')

df1.head()
# Out:
#    STT       Country Continents  Rate of users Internet (%)  \
# 0    1       Algeria   Africa                          47.0
# 1    2        Angola   Africa                          15.0
# 2    3         Benin   Africa                          13.0
# 3    4      Botswana   Africa                          21.0
# 4    5  Burkina Faso   Africa                           4.5
#
#    Smart Device  (%)  Revenue of e-commerce platforms (billion USD)  \
# 0               68.0                                           0.50
# 1               44.3                                           0.25
# 2               55.0                                           0.12
# 3               77.0                                           0.20
# 4               65.5                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# ...

# %%
# view dimensions of dataset

df1.shape
# Out:
# (1463, 14)

# %%
#Sao chép dữ liệu
df = df1

# %%
df.head()
# Out:
#    STT       Country Continents  Rate of users Internet (%)  \
# 0    1       Algeria   Africa                          47.0
# 1    2        Angola   Africa                          15.0
# 2    3         Benin   Africa                          13.0
# 3    4      Botswana   Africa                          21.0
# 4    5  Burkina Faso   Africa                           4.5
#
#    Smart Device  (%)  Revenue of e-commerce platforms (billion USD)  \
# 0               68.0                                           0.50
# 1               44.3                                           0.25
# 2               55.0                                           0.12
# 3               77.0                                           0.20
# 4               65.5                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# ...

# %%
#Loại bỏ các hàng ở dưới
df = df[:1520].dropna()
df.tail()
# Out:
#        STT      Country      Continents  Rate of users Internet (%)  \
# 1458  1459     Malaysia  Southeast Asia                        93.0
# 1459  1460    Indonesia  Southeast Asia                        80.0
# 1460  1461  Philippines  Southeast Asia                        80.0
# 1461  1462       Brunei  Southeast Asia                        97.5
# 1462  1463  Timor-Leste  Southeast Asia                        40.0
#
#       Smart Device  (%)  Revenue of e-commerce platforms (billion USD)  \
# 1458               95.0                                        560.000
# 1459               92.0                                        580.000
# 1460               96.0                                         10.000
# 1461               94.0                                          0.150
# 1462               82.0                                          0.012
#
#       Revenue of IT industry (billion USD)  \
# 1458                                 5.120
# ...

# %%
df.shape
# Out:
# (1463, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1463 entries, 0 to 1462
# Data columns (total 14 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   STT                                                                1463 non-null   int64
#  1   Country                                                            1463 non-null   object
#  2   Continents                                                         1463 non-null   object
#  3   Rate of users Internet (%)                                         1463 non-null   float64
#  4   Smart Device  (%)                                                  1463 non-null   float64
#  5   Revenue of e-commerce platforms (billion USD)                      1463 non-null   float64
#  6   Revenue of IT industry (billion USD)                               1463 non-null   float64
# ...

# %%
df['Country'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cabo Verde (Cape Verde)', 'Cameroon',
#        'Central African Republic', 'Chad', 'Comoros',
#        'Congo, Democratic Republic of the (DR Congo)',
#        'Congo, Republic of the (Republic of the Congo)', 'Djibouti',
#        'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini (Swaziland)',
#        'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau',
#        "Ivory Coast (Côte d'Ivoire)", 'Kenya', 'Lesotho', 'Liberia',
#        'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania',
#        'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe', 'Canada',
#        'The United States', 'Mexico', 'Belize', 'Costa Rica',
# ...

# %%
# drop stt
df = df.drop(columns=['STT'])

# %%
df.head()
# Out:
#         Country Continents  Rate of users Internet (%)  Smart Device  (%)  \
# 0       Algeria   Africa                          47.0               68.0
# 1        Angola   Africa                          15.0               44.3
# 2         Benin   Africa                          13.0               55.0
# 3      Botswana   Africa                          21.0               77.0
# 4  Burkina Faso   Africa                           4.5               65.5
#
#    Revenue of e-commerce platforms (billion USD)  \
# 0                                           0.50
# 1                                           0.25
# 2                                           0.12
# 3                                           0.20
# 4                                           0.10
#
#    Revenue of IT industry (billion USD)  \
# 0                                  0.80
# 1                                  0.37
# 2                                  0.07
# 3                                  0.20
# ...

# %%
# Kiểm tra các giá trị bị thiếu
print(df.isnull().sum())

# Xử lý giá trị thiếu
df.fillna(df.mean(), inplace=True)
# Out:
# Country                                                              0
# Continents                                                           0
# Rate of users Internet (%)                                           0
# Smart Device  (%)                                                    0
# Revenue of e-commerce platforms (billion USD)                        0
# Revenue of IT industry (billion USD)                                 0
# Funding in digital infrastructure (billion USD)                      0
# Foreign investment capital (billion USD)                             0
# CREDIT and BANKING digital transformation ratio(%)                   0
# Number of Enterprises Applying Digital Transformation (bussiness)    0
# Economic Growth Rate of Education (% GDP)                            0
# Number of technology start up businesses                             0
# Year                                                                 0
# dtype: int64
# ...

# %%
#Đếm các giá trị có trong mỗi cột
for col in df.columns:
  print(df[col].value_counts())
# Out:
# Country
# Algeria        11
# Paraguay       11
# Palestine      11
# Syria          11
# Nepal          11
#                ..
# Rwanda         11
# Nigeria        11
# Niger          11
# Namibia        11
# Timor-Leste    11
# Name: count, Length: 133, dtype: int64
# Continents
# Africa            594
# America           385
# Europe            220
# Asia              143
# Southeast Asia    121
# Name: count, dtype: int64
# Rate of users Internet (%)
# 80.0    32
# 50.0    31
# 70.0    29
# 90.0    27
# 85.0    27
#         ..
# 31.6     1
# 10.2     1
# 32.3     1
# 80.1     1
# 62.5     1
# Name: count, Length: 227, dtype: int64
# Smart Device  (%)
# 98.0    48
# 92.0    47
# 90.0    46
# 80.0    45
# 94.0    43
#         ..
# 82.6     1
# 76.7     1
# 68.5     1
# 54.2     1
# 99.4     1
# Name: count, Length: 147, dtype: int64
# Revenue of e-commerce platforms (billion USD)
# 0.250      62
# 0.300      57
# 0.120      49
# 0.200      49
# 0.150      49
#            ..
# ...

# %%
df.isnull().sum()
# Out:
# Country                                                              0
# Continents                                                           0
# Rate of users Internet (%)                                           0
# Smart Device  (%)                                                    0
# Revenue of e-commerce platforms (billion USD)                        0
# Revenue of IT industry (billion USD)                                 0
# Funding in digital infrastructure (billion USD)                      0
# Foreign investment capital (billion USD)                             0
# CREDIT and BANKING digital transformation ratio(%)                   0
# Number of Enterprises Applying Digital Transformation (bussiness)    0
# Economic Growth Rate of Education (% GDP)                            0
# Number of technology start up businesses                             0
# Year                                                                 0
# dtype: int64

# %%
# Declare feature vector and target variable
X = df.drop(['Country'], axis = 1)
y = df['Country']

# %%
# split data into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#check
X_train.shape, X_test.shape
# Out:
# ((980, 12), (483, 12))

# %%
# check data types in X_train

X_train.dtypes
# Out:
# Continents                                                            object
# Rate of users Internet (%)                                           float64
# Smart Device  (%)                                                    float64
# Revenue of e-commerce platforms (billion USD)                        float64
# Revenue of IT industry (billion USD)                                 float64
# Funding in digital infrastructure (billion USD)                      float64
# Foreign investment capital (billion USD)                             float64
# CREDIT and BANKING digital transformation ratio(%)                   float64
# Number of Enterprises Applying Digital Transformation (bussiness)      int64
# Economic Growth Rate of Education (% GDP)                            float64
# Number of technology start up businesses                               int64
# Year                                                                   int64
# dtype: object

# %%
X_train.head()
# Out:
#           Continents  Rate of users Internet (%)  Smart Device  (%)  \
# 1024          Asia                         92.16               96.5
# 1258         America                       64.00               77.0
# 736          America                       42.00               56.0
# 614          America                       78.00               81.0
# 787   Southeast Asia                       92.00               97.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 1024                                          90.00
# 1258                                           0.50
# 736                                            0.15
# 614                                            1.80
# 787                                          190.00
#
#       Revenue of IT industry (billion USD)  \
# 1024                                220.00
# 1258                                  0.38
# 736                                   0.15
# 614                                   1.15
# ...

# %%
X_test.head()
# Out:
#      Continents  Rate of users Internet (%)  Smart Device  (%)  \
# 1176    Europe                         96.0               99.5
# 175    Africa                          70.0               85.0
# 275    Africa                           6.0               57.0
# 548    Africa                           3.5               38.0
# 867     America                        82.0               93.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 1176                                          40.50
# 175                                            0.10
# 275                                            0.10
# 548                                            0.15
# 867                                            2.20
#
#       Revenue of IT industry (billion USD)  \
# 1176                                  5.80
# 175                                   0.11
# 275                                   0.09
# 548                                   0.10
# 867                                   1.05
#
# ...

# %%
# Sử dụng One-Hot Encoding cho cột 'Continents'
X_train = pd.get_dummies(X_train, columns=['Continents'])

X_test = pd.get_dummies(X_test, columns=['Continents'])

# %%
X_test.head()
# Out:
#       Rate of users Internet (%)  Smart Device  (%)  \
# 1176                        96.0               99.5
# 175                         70.0               85.0
# 275                          6.0               57.0
# 548                          3.5               38.0
# 867                         82.0               93.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 1176                                          40.50
# 175                                            0.10
# 275                                            0.10
# 548                                            0.15
# 867                                            2.20
#
#       Revenue of IT industry (billion USD)  \
# 1176                                  5.80
# 175                                   0.11
# 275                                   0.09
# 548                                   0.10
# 867                                   1.05
#
#       Funding in digital infrastructure (billion USD)  \
# ...

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier

rfc = RandomForestClassifier(random_state=0)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.8447

# %%
# Loại bỏ khoảng trắng, thay dấy , -> .
X_train = X_train.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Chuyển string -> float
X_train = X_train.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.replace(',', '').astype(float) if x.dtype == "object" else x)

# %% [markdown]
# =>    te

# %%
X_train.head(10)
# Out:
#       Rate of users Internet (%)  Smart Device  (%)  \
# 1024                       92.16               96.5
# 1258                       64.00               77.0
# 736                        42.00               56.0
# 614                        78.00               81.0
# 787                        92.00               97.0
# 1271                       78.00               97.5
# 506                        74.00               84.0
# 308                        75.00               87.0
# 461                        38.00               52.0
# 1423                       90.00               95.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 1024                                          90.00
# 1258                                           0.50
# 736                                            0.15
# 614                                            1.80
# 787                                          190.00
# 1271                                           0.30
# ...

# %%
# Loại bỏ khoảng trắng đầu cuối
X_train = X_train.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
# Thay dấu phẩy, chuyển thành float, và thay giá trị không hợp lệ bằng 0
X_train = X_train.apply(lambda x: pd.to_numeric(x.str.replace(',', ''), errors='coerce').fillna(0) if x.dtype == "object" else x)
X_test = X_test.apply(lambda x: pd.to_numeric(x.str.replace(',', ''), errors='coerce').fillna(0) if x.dtype == "object" else x)

# %%
X_train.head(10)
# Out:
#       Rate of users Internet (%)  Smart Device  (%)  \
# 1024                       92.16               96.5
# 1258                       64.00               77.0
# 736                        42.00               56.0
# 614                        78.00               81.0
# 787                        92.00               97.0
# 1271                       78.00               97.5
# 506                        74.00               84.0
# 308                        75.00               87.0
# 461                        38.00               52.0
# 1423                       90.00               95.0
#
#       Revenue of e-commerce platforms (billion USD)  \
# 1024                                          90.00
# 1258                                           0.50
# 736                                            0.15
# 614                                            1.80
# 787                                          190.00
# 1271                                           0.30
# ...

# %%
# @title Rate of users Internet (%) vs Smart Device  (%)

from matplotlib import pyplot as plt
X_train.plot(kind='scatter', x='Rate of users Internet (%)', y='Smart Device  (%)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier

rfc = RandomForestClassifier(random_state=0)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.8447

# %%
# instantiate the classifier with n_estimators = 100

rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set

rfc_100.fit(X_train, y_train)

# Predict on the test set results

y_pred_100 = rfc_100.predict(X_test)

# Check accuracy score

print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred_100)))
# Out:
# Model accuracy score with 100 decision-trees : 0.8447

# %% [markdown]
# Độ chính xác của mô hình với 10 cây quyết định là 0.8847 bằng với 100 cây quyết định -> Có tính ổn định

# %%
# create the classifier with n_estimators = 100

clf = RandomForestClassifier(n_estimators=100, random_state=0)

# fit the model to the training set

clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# view the feature scores

feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
# Revenue of IT industry (billion USD)                                 0.123012
# Economic Growth Rate of Education (% GDP)                            0.119723
# Number of technology start up businesses                             0.109030
# Foreign investment capital (billion USD)                             0.099694
# Revenue of e-commerce platforms (billion USD)                        0.098142
# Funding in digital infrastructure (billion USD)                      0.090394
# CREDIT and BANKING digital transformation ratio(%)                   0.079178
# Rate of users Internet (%)                                           0.070678
# Number of Enterprises Applying Digital Transformation (bussiness)    0.070155
# Smart Device  (%)                                                    0.061052
# Year                                                                 0.025033
# Continents_America                                                   0.012814
# ...

# %%
# Creating a seaborn bar plot

sns.barplot(x=feature_scores, y=feature_scores.index)

# Add labels to the graph

plt.xlabel('Feature Importance Score')

plt.ylabel('Features')

# Add title to the graph

plt.title("Visualizing Important Features")


# Visualize the graph

plt.show()
